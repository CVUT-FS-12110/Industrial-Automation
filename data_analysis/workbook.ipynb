# %% [markdown]
# # Data analysis workbook

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
from scipy import optimize

# %% [markdown]
# ## Single time series
# - remove abnormaliy high/low values from data
# - find min, max, range, mean, std, median
# - z-score the data

# %%
N = 200
t = np.cumsum(np.random.random(N) * 3)
x = 2 * np.sin(t /  (3 * 2 * np.pi)) + 0.5 * np.sin(t /  (0.74 * 2 * np.pi)) + np.linspace(0, 1, N) + np.random.normal(0, 0.2, N)
x[[100, 125, 173]] = 10

plt.figure(figsize=(10, 4))
plt.plot(t, x)
plt.xlabel("Time [-]")
plt.ylabel("x [-]")
plt.show()

# %% [markdown]
# ## Correlation of two time series
#
# * find a lag between two signals via maximum correlation

# %%
N = 10000
x = 5 * np.sin(np.linspace(0,20,N)) + np.random.normal(0,1,N)
y = 5 * np.sin(np.linspace(5,25,N)) + np.random.normal(0.5,0.5,N)

plt.figure(figsize=(8, 4))
plt.plot(x)
plt.plot(y)
plt.xlabel("Time [-]")
plt.ylabel("x [-]")
plt.show()

# %% [markdown]
# ## Multiple random variables
#
# - Create a histogram of random variable with normal distribution
# - Create a histogram of random variable with uniform distribution
# - Create a histogram of sum of multiple random variables with uniform distribution
# - Create a boxplot of multiple random variables with normal distribution

# %% [markdown]
# ## Time series regression
#
# - fit coefficents to suitable equation according to the given data
# - use the obatined equation to get filtered values for provided $x$ values
# - predict future values

# %%
N = 50
x = np.linspace(0, 5, N)
y = 2 + 3 * np.exp(x * 0.8 + 1) + np.random.normal(0, 20, N)

plt.figure(figsize=(8, 4))
plt.plot(y, "b.")
plt.xlabel("x [-]")
plt.ylabel("y [-]")
plt.show()
